# %%
name = input("Enter your name: ")

print(f"Hello! My name is {name}.")
print("I am a Mathematics student at the University of Lagos with an interest in AI and Machine Learning.")
# Out:
# Hello! My name is Mariam.
# I am a Mathematics student at the University of Lagos with an interest in AI and Machine Learning.
